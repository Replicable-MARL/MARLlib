# %% [markdown]
# ## Python Intrepreter Setting Up
#
# Install a minicode to make our project use python3.8. Because of our package dependancy, our project is running on python3.8 currently. However, the mechanism does not support to change the defaulted python3.10 kernel to other python kernels.  Therefore, we need make python3.8 by ourself.
#
# The method is by installing a miniconda, and setting the python kerynel by commd.

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge 
# !python -m ipykernel install --name "py38" --user

# %% [markdown]
# ##  Installing required packages.
#
# + Protobuf is to fix a feature on google colab.
# + marllib, our main package
# + **ray[rllib], gym**, because of the kernel changed in google colab, we need installed this package explicitly.

# %%
# !/usr/local/bin/pip install protobuf==3.20.0 marllib==1.0.3 ray[rllib] gym==0.21.0

# %% [markdown]
# ## Persist sourcode to a file
#
# If we run ```import xxxx``` directly in google colab, the google colab sitll will call its default kernel.
#
# Therefore, we need to use ```usr/local/bin/python3.8```, which was installed in the previous step, to run our program by given a file.

# %%
example_usage = """
from marllib import marl

# prepare env
env = marl.make_env(environment_name="mpe", map_name="simple_spread")

# initialize algorithm with appointed hyper-parameters
mappo = marl.algos.mappo(hyperparam_source="mpe")

# build agent model based on env + algorithms + user preference
model = marl.build_model(env, mappo, {"core_arch": "mlp", "encode_layer": "128-256"})

# start training
mappo.fit(env, model, stop={'episode_reward_mean': 2000, 'timesteps_total': 10000000}, local_mode=False, num_gpus=0,
          num_workers=1, share_policy='group', checkpoint_freq=50)
"""


with open("marllib_script.py", "w") as file:
    file.write(example_usage)

# %% [markdown]
# ## settig environement variable to make python runnable

# %%
# !export PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python

# %% [markdown]
# ## Run our program finally

# %%
# !/usr/local/bin/python3.8 marllib_script.py
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# == Status ==
# Current time: 2023-05-25 02:22:16 (running for 01:59:02.56)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    489 |          7111.47 | 1564800 | -77.5739 |             -56.1584 |             -118.493 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:22 (running for 01:59:08.54)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    490 |          7124.43 | 1568000 | -81.8324 |             -57.8292 |              -138.17 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:27 (running for 01:59:13.56)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    490 |          7124.43 | 1568000 | -81.8324 |             -57.8292 |              -138.17 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:32 (running for 01:59:18.56)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    490 |          7124.43 | 1568000 | -81.8324 |             -57.8292 |              -138.17 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:38 (running for 01:59:24.37)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    491 |          7140.25 | 1571200 | -79.3674 |             -55.5277 |              -116.56 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:43 (running for 01:59:29.38)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    491 |          7140.25 | 1571200 | -79.3674 |             -55.5277 |              -116.56 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:48 (running for 01:59:34.40)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    491 |          7140.25 | 1571200 | -79.3674 |             -55.5277 |              -116.56 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:53 (running for 01:59:39.45)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |    492 |          7154.27 | 1574400 | -79.8096 |              -55.815 |              -120.25 |                 25 |
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Current time: 2023-05-25 02:22:58 (running for 01:59:44.46)
# Memory usage on this node: 1.7/12.7 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.1 GiB heap, 0.0/3.55 GiB objects
# Result logdir: /content/exp_results/mappo_mlp_simple_spread
# Number of trials: 1/1 (1 RUNNING)
# +--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name                                 | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |--------------------------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | MAPPOTrainer_mpe_simple_spread_564de_00000 | RUNNING  | 172.28.0.12:7196 |